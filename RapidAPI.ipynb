# %% [markdown]
# <a href="https://colab.research.google.com/github/nadaelbeyali/BAN3110-Homework/blob/main/RapidAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#RapidAPI Marketplace is the world's largest API hub, serving as a centralized platform where developers can discover, test and connect to thousands of public APIs

# %%
import http.client

conn = http.client.HTTPSConnection("songstats.p.rapidapi.com")
my_key = "f828efe8ffmsh8213c422e338731p1a3801jsn5299c4bc7536"

headers = {
    'x-rapidapi-key': my_key,
    'x-rapidapi-host': "songstats.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/tracks/info?spotify_track_id=3VTPi12rK7mioSLL0mmu75&songstats_track_id=2iye8blt&apple_music_track_id=1567644047&isrc=GBKQU2166610", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"result":"success","message":"Data Retrieved.","track_info":{"songstats_track_id":"2iye8blt","avatar":"https://i.scdn.co/image/ab67616d00001e02170a837618b7f461392a3e84","site_url":"https://songstats.com/track/2iye8blt/tears-for-later","release_date":"2021-07-30","title":"Tears For Later","artists":[{"name":"Galantis","songstats_artist_id":"6s7ie3pn"},{"name":"Don Diablo","songstats_artist_id":"48ra1cnv"}],"is_remix":false,"collaborators":[{"name":"Lova Sönnerbo","roles":["Songwriter"],"songstats_collaborator_id":"8j9qhtw1"},{"name":"Will Simms","roles":["Songwriter"],"songstats_collaborator_id":"ac6g5eb0"},{"name":"Nick Sheldon","roles":["Songwriter"],"songstats_collaborator_id":"uc5m3nax"},{"name":"Yk Koi","roles":["Composer"],"songstats_collaborator_id":"ebqjyl5z"},{"name":"Etta Zelmani","roles":["Songwriter"],"songstats_collaborator_id":"gcle3dwb"},{"name":"Christian Karlsson","roles":["Composer"],"songstats_collaborator_id":"z3a2bs6m"},{"name":"Don Pepijn Schipper","roles":["Com
# ...

# %%
from pprint import pprint
pprint(data.decode("utf-8"))
# Out:
# ('{"result":"success","message":"Data '
#  'Retrieved.","track_info":{"songstats_track_id":"2iye8blt","avatar":"https://i.scdn.co/image/ab67616d00001e02170a837618b7f461392a3e84","site_url":"https://songstats.com/track/2iye8blt/tears-for-later","release_date":"2021-07-30","title":"Tears '
#  'For '
#  'Later","artists":[{"name":"Galantis","songstats_artist_id":"6s7ie3pn"},{"name":"Don '
#  'Diablo","songstats_artist_id":"48ra1cnv"}],"is_remix":false,"collaborators":[{"name":"Lova '
#  'Sönnerbo","roles":["Songwriter"],"songstats_collaborator_id":"8j9qhtw1"},{"name":"Will '
#  'Simms","roles":["Songwriter"],"songstats_collaborator_id":"ac6g5eb0"},{"name":"Nick '
#  'Sheldon","roles":["Songwriter"],"songstats_collaborator_id":"uc5m3nax"},{"name":"Yk '
#  'Koi","roles":["Composer"],"songstats_collaborator_id":"ebqjyl5z"},{"name":"Etta '
#  'Zelmani","roles":["Songwriter"],"songstats_collaborator_id":"gcle3dwb"},{"name":"Christian '
# ...
